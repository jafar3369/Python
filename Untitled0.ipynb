# %% [markdown]
# <a href="https://colab.research.google.com/github/jafar3369/jafar3369/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pytube
# Out:
# ...
#      |████████████████████████████████| 56 kB 3.7 MB/s
# ...

# %%
from pytube import YouTube

# %%
#https://www.youtube.com/watch?v=nqye02H_H6I
from IPython.display import YouTubeVideo
YouTubeVideo('nqye02H_H6I' , width = 1000)

# %%
yt = YouTube('https://youtu.be/D63tvoMopQI')

# %%
yt.title
# Out:
# 'Project 4 - NETFLIX: COMPILATION GENERATOR'

# %%
stream = yt.streams.get_by_itag(22)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-961423df2856> in <module>()
# ----> 1 stream = yt.streams.get_by_itag(22)
#
# /usr/local/lib/python3.7/dist-packages/pytube/__main__.py in streams(self)
#     290         """
#     291         self.check_availability()
# --> 292         return StreamQuery(self.fmt_streams)
#     293
#     294     @property
#
# /usr/local/lib/python3.7/dist-packages/pytube/__main__.py in fmt_streams(self)
#     175         # https://github.com/pytube/pytube/issues/1054
#     176         try:
# --> 177             extract.apply_signature(stream_manifest, self.vid_info, self.js)
#     178         except exceptions.ExtractError:
#     179             # To force an update to the js file, we clear the cache and retry
#
# /usr/local/lib/python3.7/dist-packages/pytube/extract.py in apply_signature(stream_manifest, vid_info, js)
#     407
# ...

# %%
pip install --upgrade pytube
# Out:
# ...
#   Using cached pytube-11.0.2-py3-none-any.whl (56 kB)
# ...
#   Attempting uninstall: pytube
#     Found existing installation: pytube 11.0.1
#     Uninstalling pytube-11.0.1:
#       Successfully uninstalled pytube-11.0.1
# ...

# %%
yt.views
# Out:
# 97463

# %%
pip install git+https://github.com/pytube/pytube
# Out:
# ...
#   Cloning https://github.com/pytube/pytube to /tmp/pip-req-build-mr6r7g0s
#   Running command git clone -q https://github.com/pytube/pytube /tmp/pip-req-build-mr6r7g0s

# %%
pip install git+https://github.com/mytja/pytube
# Out:
# ...
#   Cloning https://github.com/mytja/pytube to /tmp/pip-req-build-w6ugubn8
#   Running command git clone -q https://github.com/mytja/pytube /tmp/pip-req-build-w6ugubn8
# ...
#   Created wheel for pytube: filename=pytube-11.0.1-py3-none-any.whl size=56242 sha256=dc82046c43fe9b21e919bfe8545f21ced2f2aacf3136823b37a4db00425e06a3
#   Stored in directory: /tmp/pip-ephem-wheel-cache-2rxe1bvz/wheels/da/a2/95/308838f31174d736cf6fdf320f6b53ddce0ebc5f8860e32620
# Successfully built pytube
# ...
#   Attempting uninstall: pytube
#     Found existing installation: pytube 11.0.2
#     Uninstalling pytube-11.0.2:
#       Successfully uninstalled pytube-11.0.2
# ...
